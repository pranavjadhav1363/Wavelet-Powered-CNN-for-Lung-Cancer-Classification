# %%
import pandas as pd
import numpy as np
import os
from PIL import Image
import os
import shutil
from numpy.linalg import svd
import cv2
import pywt
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
def apply_gaussian_blur(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            img_path = os.path.join(input_folder, filename)
            img = cv2.imread(img_path)
            blurred_img = cv2.GaussianBlur(img, (3, 3), 0)
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, blurred_img)

            print(f"Processed and saved: {filename}")

# %%
input_folder = "../DATA_PROCESSED/Pywavelet/Bengin/"
output_folder = "../DATA_PROCESSED/256x256_Guas/Bengin"

apply_gaussian_blur(input_folder, output_folder)
# Out:
# Processed and saved: Bengin case (1)_bior1.1_horizontal.png
# Processed and saved: Bengin case (1)_bior1.1_vertical.png
# Processed and saved: Bengin case (1)_bior1.3_horizontal.png
# Processed and saved: Bengin case (1)_bior1.3_vertical.png
# Processed and saved: Bengin case (1)_bior1.5_horizontal.png
# Processed and saved: Bengin case (1)_bior1.5_vertical.png
# Processed and saved: Bengin case (1)_db1_horizontal.png
# Processed and saved: Bengin case (1)_db1_vertical.png
# Processed and saved: Bengin case (1)_haar_horizontal.png
# Processed and saved: Bengin case (1)_haar_vertical.png
# Processed and saved: Bengin case (1)_rbio1.1_horizontal.png
# Processed and saved: Bengin case (1)_rbio1.1_vertical.png
# Processed and saved: Bengin case (1)_rbio3.1_horizontal.png
# Processed and saved: Bengin case (1)_rbio3.1_vertical.png
# Processed and saved: Bengin case (10)_bior1.1_horizontal.png
# Processed and saved: Bengin case (10)_bior1.1_vertical.png
# ...

# %%
input_folder = "../DATA_PROCESSED/Pywavelet/Malignant/"
output_folder = "../DATA_PROCESSED/256x256_Guas/Malignant/"

apply_gaussian_blur(input_folder, output_folder)
# Out:
# Processed and saved: Malignant case (1)_bior1.1_horizontal.png
# Processed and saved: Malignant case (1)_bior1.1_vertical.png
# Processed and saved: Malignant case (1)_bior1.3_horizontal.png
# Processed and saved: Malignant case (1)_bior1.3_vertical.png
# Processed and saved: Malignant case (1)_bior1.5_horizontal.png
# Processed and saved: Malignant case (1)_bior1.5_vertical.png
# Processed and saved: Malignant case (1)_db1_horizontal.png
# Processed and saved: Malignant case (1)_db1_vertical.png
# Processed and saved: Malignant case (1)_haar_horizontal.png
# Processed and saved: Malignant case (1)_haar_vertical.png
# Processed and saved: Malignant case (1)_rbio1.1_horizontal.png
# Processed and saved: Malignant case (1)_rbio1.1_vertical.png
# Processed and saved: Malignant case (1)_rbio3.1_horizontal.png
# Processed and saved: Malignant case (1)_rbio3.1_vertical.png
# Processed and saved: Malignant case (10)_bior1.1_horizontal.png
# ...

# %%
input_folder = "../DATA_PROCESSED/Pywavelet/Normal/"
output_folder = "../DATA_PROCESSED/256x256_Guas/Normal/"

apply_gaussian_blur(input_folder, output_folder)
# Out:
# Processed and saved: Normal case (1)_bior1.1_horizontal.png
# Processed and saved: Normal case (1)_bior1.1_vertical.png
# Processed and saved: Normal case (1)_bior1.3_horizontal.png
# Processed and saved: Normal case (1)_bior1.3_vertical.png
# Processed and saved: Normal case (1)_bior1.5_horizontal.png
# Processed and saved: Normal case (1)_bior1.5_vertical.png
# Processed and saved: Normal case (1)_db1_horizontal.png
# Processed and saved: Normal case (1)_db1_vertical.png
# Processed and saved: Normal case (1)_haar_horizontal.png
# Processed and saved: Normal case (1)_haar_vertical.png
# Processed and saved: Normal case (1)_rbio1.1_horizontal.png
# Processed and saved: Normal case (1)_rbio1.1_vertical.png
# Processed and saved: Normal case (1)_rbio3.1_horizontal.png
# Processed and saved: Normal case (1)_rbio3.1_vertical.png
# Processed and saved: Normal case (10)_bior1.1_horizontal.png
# Processed and saved: Normal case (10)_bior1.1_vertical.png
# ...
